# %% [markdown]
# # Named Entity Recognition

# %%
import spacy_transformers
import spacy 
from nltk import sent_tokenize

# %%
#!python -m spacy download en_core_web_trf

# %% [markdown]
# # Load Model

# %% [markdown]
# "en_core_web_trf" model helps with NER's

# %%
def load_model():
    nlp = spacy.load("en_core_web_trf")
    return nlp

# %%
nlp_model = load_model()

# %% [markdown]
# # Load DataSet

# %%
import os 
import sys
import pathlib
folder_path = pathlib.Path().parent.resolve()
sys.path.append(os.path.join(folder_path, '../'))
from utils import load_subtitles_dataset

# %%
dataset_path = "../data/Subtitles/"
df = load_subtitles_dataset(dataset_path)

# %%
df.head()
# Out:
#    episode                                             script
# 0        1  Gold Roger, the King of the Pirates,\n attaine...
# 1        2  Gold Roger, the King of the Pirates,\n attaine...
# 2        3  Gold Roger, the King of the Pirates,\n attaine...
# 3        4  Gold Roger, the King of the Pirates,\n attaine...
# 4        5  Gold Roger, the King of the Pirates,\n attaine...

# %%
sample_script = df.iloc[2]['script']

# %%
sample_script
# Out:
# 'Gold Roger, the King of the Pirates,\n attained everything this world has to offer.\n The words he uttered just before his death drove people to the seas.\n My treasure? If you want it, you can have it!\n Find it! I left everything this world has to offer there!\n And so men head for the Grand Line in pursuit of their dreams!\n The world has truly entered a Great Pirate Era!\n We\'re going to gather up all our dreams\n and set out in search of something to find\n ONE PIECE!\n Compasses only cause delays\n Delirious with fever, I take the helm\n If the dusty treasure map has been verified, it\'s not a legend!\n When it comes to personal storms,\n simply ride aboard someone else\'s biorhythm\n and pretend it isn\'t there!\n We\'re going to gather up all our dreams\n and set out in search of something to find\n A coin in my pocket, and do you wanna be my friend?\n We are, We are on the cruise!\n We are!\n Fire!\n What are you--?!\n Luffy-san!\n Straw Hat?!\n That doesn\'t work!\n I told you I was strong!\n W-Who the hell are you?!\n I\'m Luffy!\n The man who\'s gonna be King of the Pirates!\n "Morgan vs. Luffy! Who\'s the Mysterious Pretty Girl?"\n W-What?! The King of the Pirates?!\n Do you even know what that means?!\n King of the Pirates is King of the Pirates!\n Are there any other meanings?\n I was shocked, too!\n But Luffy-san is serious! That\'s how he is!\n He intends to become the King of the Pirates\n and obtain this world\'s ultimate treasure... the One Piece!\n Here\'s your treasure!\n Which is yours? I couldn\'t tell, so I brought three of \'em.\n All three are mine.\n I use the Three-Sword Style.\n You\'ll take \'em, right?\n If we fight together now, you\'ll be a government-defying villain!\n Would you prefer that, or being killed by the navy like this?\n What are you, the devil\'s son?!\n Well, whatever.\n I\'ll be your pirate, if I\'m just gonna die here instead!\n Hurray! So you\'ll join my crew?!\n Alright! Woo-hoo! This is great! Alright!\n Okay! Now untie these stupid ropes already!\n What... is he?\n He flung the bullets back!\n He\'s no ordinary human, that Straw Hat...\n Must\'ve eaten one of those rumored Devil Fruits!\n --A Devil Fruit?! --The hidden treasures of the sea?!\n The Devil Fruits...\n Whoever eats one is said to gain seemingly unworldly abilities.\n The power to breathe fire...\n The power to cause tsunamis...\n There are all sorts of rumors,\n but there are many types, and almost nothing is known about them.\n It\'s said the secrets to them lie in the Grand Line...\n but there\'s no question Straw Hat just displayed a devil power!\n Hurry! Hurry!\n Damn! These knots are tight!\n Hey! Quit wastin\' time!\n No matter who they are,\n everyone who opposes me gets executed!\n If guns won\'t work, then chop them to death!\n Huh, that\'s weird! It got tighter instead!\n Give me a damn sword!\n Luffy-san!\n Roronoa Zoro!\n So cool!\n Move and you\'re dead.\n Too scary!\n I\'ll be a pirate. I promise you that.\n I\'m officially a criminal, now that I\'ve fought the navy.\n But I\'ll tell you this right now.\n I\'m only going to fulfill my ambition!\n Ambition?\n To be the world\'s greatest swordsman!\n If I wind up having to give that up,\n you\'d better accept responsibility and apologize to me!\n The world\'s greatest swordsman? That sounds great!\n The King of the Pirates would need no less than that on his crew!\n You sure talk big.\n At this point, whether it\'s as a criminal or whatever else,\n I will spread my name throughout the world!\n What\'re you standing around for?! Slaughter them this instant!\n Duck, Zoro!\n Gum-Gum Whip!\n Y-You did it! Incredible!\n What the hell are you?\n I ate the Gum-Gum Fruit.\n Gum-Gum Fruit?\n A rubber person!\n So he does have Devil Fruit powers!\n Captain! We don\'t stand a chance against them!\n These guys are crazy!\n We can\'t even handle Zoro by himself!\n This is a direct order!\n Everyone who spouted weakness just now...\n must now shoot themselves i ...

# %%
sentences = sent_tokenize(sample_script)

# %%
sentences = sentences[30:200]

# %%
sentence = ".".join(sentences)

# %% [markdown]
# # Run Model

# %%
doc = nlp_model(sentence)

# %%
doc.ents
# Out:
# (Luffy,
#  the One Piece!.Here,
#  three,
#  three,
#  Three,
#  one,
#  Straw Hat,
#  the Gum-Gum Fruit,
#  Zoro,
#  "Axe-Hand,
#  Morgan,
#  Coby,
#  Straw Hat!.Check,
#  Navy,
#  "Axe-Hand" Morgan!.--Dad!.Kill,
#  Morgan,
#  the Grand Line!.I,
#  Buggy,
#  Buggy the Immortal,
#  three weeks!.Huh?.You're)

# %%
for entity in doc.ents:
    print(entity, entity.label_)
# Out:
# Luffy PERSON
# the One Piece!.Here WORK_OF_ART
# three CARDINAL
# three CARDINAL
# Three CARDINAL
# one CARDINAL
# Straw Hat PERSON
# the Gum-Gum Fruit PRODUCT
# Zoro PERSON
# "Axe-Hand PERSON
# Morgan PERSON
# Coby PERSON
# Straw Hat!.Check PERSON
# Navy ORG
# "Axe-Hand" Morgan!.--Dad!.Kill PERSON
# Morgan PERSON
# the Grand Line!.I FAC
# Buggy PERSON
# Buggy the Immortal PERSON
# three weeks!.Huh?.You're DATE

# %%
def get_ners_inference(script):
    script_senetence = sent_tokenize(script)

    ner_output = [] 
    for sentence in script_senetence:
        doc = nlp_model(sentence)
        ners = set() 
        for entity in doc.ents:
            if entity.label_ =="PERSON":
                full_name = entity.text
                first_name = entity.text.split(" ")[0]
                first_name = first_name.strip()
                ners.add(first_name)
        ner_output.append(ners)

    return ner_output

# %%
df1 = df.head(10)

# %%
df1['ners'] = df1['script'].apply(get_ners_inference)
# Out:
# C:\Users\salvi\AppData\Local\Temp\ipykernel_27352\2339167363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ners'] = df1['script'].apply(get_ners_inference)

# %%
df1['ners'][0]
# Out:
# [{'Gold'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Luffy'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Coby'},
#  set(),
#  set(),
#  {'Alvida-sama'},
#  set(),
#  set(),
#  {'Alvida-sama'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Coby'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Alvida'},
#  set(),
#  {'Coby'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Monkey'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Coby'},
#  {'Luffy'},
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Alvida'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Alvida'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Alvida-sama'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Luffy'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Luffy'},
#  set(),
#  set(),
#  set(),
#  set(),
#  {'K-K-King'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Alvida'},
#  set(),
#  {'Coby'},
#  {'Zoro'},
#  set(),
#  {'Coby'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Rocket'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Coby'},
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Luffy-san!'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Luffy'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Zoro'},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {'Roronoa'}]

# %% [markdown]
# # Character Network

# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from pyvis.network import Network

# %%
def generate_character_network(df):
    windows = 10 
    entity_relationship = [] 

    for row in df['ners']:
        previous_entities_in_window = [] 

        for sentence in row:
            previous_entities_in_window.append(list(sentence))
            previous_entities_in_window = previous_entities_in_window[-windows:]

            #Flatten 2D into 1D list 
            previous_entities_flattened = sum(previous_entities_in_window, [])
            
            for entity in sentence:
                for entity_in_window in previous_entities_flattened:
                    if entity != entity_in_window:
                        entity_relationship.append(sorted([entity, entity_in_window]))

    
    relationship_df = pd.DataFrame({'value': entity_relationship})
    relationship_df['source'] = relationship_df['value'].apply(lambda x: x[0])
    relationship_df['target'] = relationship_df['value'].apply(lambda x: x[1])
    relationship_df = relationship_df.groupby(['source', 'target']).count().reset_index()
    relationship_df = relationship_df.sort_values('value', ascending=False)

    return relationship_df

# %%
relationship_df = generate_character_network(df1)

# %%
relationship_df
# Out:
#     source      target  value
# 96   Luffy        Zoro     13
# 37   Buggy      Shanks      9
# 90   Luffy      Shanks      8
# 88   Luffy      Morgan      7
# 86   Luffy  Luffy-san!      7
# ..     ...         ...    ...
# 25     Big        Zoro      1
# 23   Berry  Makino-san      1
# 21   Beast       Mohji      1
# 55  Carrot      Pepper      1
# 91   Luffy       Straw      1
#
# [128 rows x 3 columns]

# %%
relationship_df[relationship_df['value']!=1]
# Out:
#         source      target  value
# 96       Luffy        Zoro     13
# 37       Buggy      Shanks      9
# 90       Luffy      Shanks      8
# 88       Luffy      Morgan      7
# 86       Luffy  Luffy-san!      7
# ..         ...         ...    ...
# 4   "Axe-Hand"        Zoro      2
# 22       Beast       Tamer      2
# 36       Buggy     Roronoa      2
# 24         Big       Luffy      2
# 30       Buggy    Chouchou      2
#
# [66 rows x 3 columns]

# %%
#For Cleaner Purpose
relationship_df = relationship_df.head(90)

# %%
G = nx.from_pandas_edgelist(
    relationship_df, 
    source='source', 
    target='target', 
    edge_attr='value',
    create_using=nx.Graph()
)

net = Network(notebook=True, width="1000px", height="700px", bgcolor="#222222", font_color="white", cdn_resources="remote")
node_degree = dict(G.degree)

nx.set_node_attributes(G, node_degree, 'size')
net.from_nx(G)
net.show("luffy_demo.html")
# Out:
# luffy_demo.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="luffy_demo.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
